# %%
import pandas as pd 
import numpy as np 
import warnings
warnings.filterwarnings("ignore")

# %%
#read data that from 2005 to 2014
accident_data = pd.read_csv('/kaggle/input/uk-accidents-10-years-history-with-many-variables/Accidents0514.csv')
vehicles_data = pd.read_csv('/kaggle/input/uk-accidents-10-years-history-with-many-variables/Vehicles0514.csv')
casualties_data = pd.read_csv('/kaggle/input/uk-accidents-10-years-history-with-many-variables/Casualties0514.csv')

# %%
accident_data.shape

# %%
accident_data.head()

# %%
vehicles_data.shape

# %%
vehicles_data.head()

# %%
casualties_data.shape

# %%
casualties_data.head()

# %%
accident_data.replace(-1, 'NaN', inplace=True)
vehicles_data.replace(-1, 'NaN', inplace=True)
casualties_data.replace(-1, 'NaN', inplace=True)

# %%
casualties_data.head()

# %%
final_data = pd.merge(accident_data, casualties_data, on='Accident_Index', how='left')
final_data = pd.merge(final_data, vehicles_data, on='Accident_Index', how='left')

# %%
final_data.head()

# %%
print(final_data.columns)

# %%
import pandas as pd

column_names = ['Accident_Index', 'Location_Easting_OSGR', 'Location_Northing_OSGR',
       'Longitude', 'Latitude', 'Police_Force', 'Accident_Severity',
       'Number_of_Vehicles', 'Number_of_Casualties', 'Date', 'Day_of_Week',
       'Time', 'Local_Authority_(District)', 'Local_Authority_(Highway)',
       '1st_Road_Class', '1st_Road_Number', 'Road_Type', 'Speed_limit',
       'Junction_Detail', 'Junction_Control', '2nd_Road_Class',
       '2nd_Road_Number', 'Pedestrian_Crossing-Human_Control',
       'Pedestrian_Crossing-Physical_Facilities', 'Light_Conditions',
       'Weather_Conditions', 'Road_Surface_Conditions',
       'Special_Conditions_at_Site', 'Carriageway_Hazards',
       'Urban_or_Rural_Area', 'Did_Police_Officer_Attend_Scene_of_Accident',
       'LSOA_of_Accident_Location', 'Vehicle_Reference_x',
       'Casualty_Reference', 'Casualty_Class', 'Sex_of_Casualty',
       'Age_of_Casualty', 'Age_Band_of_Casualty', 'Casualty_Severity',
       'Pedestrian_Location', 'Pedestrian_Movement', 'Car_Passenger',
       'Bus_or_Coach_Passenger', 'Pedestrian_Road_Maintenance_Worker',
       'Casualty_Type', 'Casualty_Home_Area_Type', 'Vehicle_Reference_y',
       'Vehicle_Type', 'Towing_and_Articulation', 'Vehicle_Manoeuvre',
       'Vehicle_Location-Restricted_Lane', 'Junction_Location',
       'Skidding_and_Overturning', 'Hit_Object_in_Carriageway',
       'Vehicle_Leaving_Carriageway', 'Hit_Object_off_Carriageway',
       '1st_Point_of_Impact', 'Was_Vehicle_Left_Hand_Drive?',
       'Journey_Purpose_of_Driver', 'Sex_of_Driver', 'Age_of_Driver',
       'Age_Band_of_Driver', 'Engine_Capacity_(CC)', 'Propulsion_Code',
       'Age_of_Vehicle', 'Driver_IMD_Decile', 'Driver_Home_Area_Type']

# Convert the list to a pandas Series
column_series = pd.Series(column_names)

# Check for duplicates
duplicates = column_series[column_series.duplicated()]
if not duplicates.empty:
    print("Duplicated column names:")
    print(duplicates)
else:
    print("No duplicated column names found.")

# %%
df = final_data.copy()

# %%
df.head()

# %%
# !pip install xlrd

# %%
df.columns.duplicated()

# %%
# Read the Excel file and sheet
casualty_severity = pd.read_excel("/kaggle/input/uk-accidents-10-years-history-with-many-variables/Road-Accident-Safety-Data-Guide.xls", sheet_name="Accident Severity")

# Perform left join
df = pd.merge(df, casualty_severity, left_on="Casualty_Severity", right_on="code", how="left")

# Rename the column
df.rename(columns={"label": "Casualty_Outcome"}, inplace=True)

# Optionally, remove the temporary variable
del casualty_severity

# %%
# Merge Accidents and Casualties dataframes on 'Accident_Index'
df = pd.merge(accident_data, casualties_data, on='Accident_Index')

# Merge df with Vehicles dataframe on 'Accident_Index'
df = pd.merge(df, vehicles_data, on='Accident_Index')

# Optionally, remove Accidents, Casualties, and Vehicles dataframes
del accident_data, casualties_data, vehicles_data

# %%
#read data that from 2005 to 2014
accident_data = pd.read_csv('/kaggle/input/uk-accidents-10-years-history-with-many-variables/Accidents0514.csv')
vehicles_data = pd.read_csv('/kaggle/input/uk-accidents-10-years-history-with-many-variables/Vehicles0514.csv')
casualties_data = pd.read_csv('/kaggle/input/uk-accidents-10-years-history-with-many-variables/Casualties0514.csv')
# Merge Accidents and Casualties dataframes on 'Accident_Index'
df = pd.merge(accident_data, casualties_data, on='Accident_Index')

# Merge df with Vehicles dataframe on 'Accident_Index'
df = pd.merge(df, vehicles_data, on='Accident_Index')

# Optionally, remove Accidents, Casualties, and Vehicles dataframes
del accident_data, casualties_data, vehicles_data

# %%
# Read the Excel file and sheet
casualty_severity = pd.read_excel("/kaggle/input/uk-accidents-10-years-history-with-many-variables/Road-Accident-Safety-Data-Guide.xls", sheet_name="Accident Severity")

# Perform left join
df = pd.merge(df, casualty_severity, left_on="Casualty_Severity", right_on="code", how="left")

# Rename the column
df.rename(columns={"label": "Casualty_Outcome"}, inplace=True)

# Optionally, remove the temporary variable
del casualty_severity

# %%
# Read the Excel file and sheet
location_code = pd.read_excel("/kaggle/input/uk-accidents-10-years-history-with-many-variables/Road-Accident-Safety-Data-Guide.xls", sheet_name="Police Force")

# Perform left join
df = pd.merge(df, location_code, left_on="Police_Force", right_on="code", how="left")

# Rename the column
df.rename(columns={"label": "Location"}, inplace=True)

# Optionally, remove the temporary variable
del location_code

# %%
# Read the Excel file and sheet
light_conditions = pd.read_excel("/kaggle/input/uk-accidents-10-years-history-with-many-variables/Road-Accident-Safety-Data-Guide.xls", sheet_name="Light Conditions")

# Perform left join with specified suffixes
df = pd.merge(df, light_conditions, left_on="Light_Conditions", right_on="code", how="left", suffixes=('_main', '_light'))

# Rename the column
df.rename(columns={"label_light": "Lighting"}, inplace=True)

# Optionally, remove the temporary variable
del light_conditions

# %%
# Read the weather conditions data
weather_conditions = pd.read_excel("/kaggle/input/uk-accidents-10-years-history-with-many-variables/Road-Accident-Safety-Data-Guide.xls", sheet_name="Weather")

# Perform left join to map weather condition codes to labels with specified suffixes
df = pd.merge(df, weather_conditions, left_on="Weather_Conditions", right_on="code", how="left", suffixes=('_main', '_weather'))

# Rename the column
df.rename(columns={"label_weather": "Weather"}, inplace=True)

# Perform left join to map weather condition codes to labels
df = pd.merge(df, weather_conditions, left_on="Weather_Conditions", right_on="code", how="left")

# Rename the column
df.rename(columns={"label": "Weather"}, inplace=True)

# Optionally, remove the temporary variable
del weather_conditions

# %% [markdown]
# \\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\

# %%
df.head()

# %%
# Check for missing values in the entire DataFrame
missing_values = final_data.isnull()

# Count the number of missing values in each column
missing_counts = final_data.isnull().sum()

# Calculate the percentage of missing values in each column
missing_percentages = (final_data.isnull().sum() / len(final_data)) * 100

# Print the results
print("Missing value counts:")
print(missing_counts)
print("\nMissing value percentages:")
print(missing_percentages)

# Alternatively, you can print missing values per column directly
print("\nMissing values per column:")
print(final_data.isnull().sum())

# %% [markdown]
# Dealing with missing values

# %%
# Remove rows with missing values
final_data_cleaned = final_data.dropna()

# Remove columns with missing values
final_data_cleaned = final_data.dropna(axis=1)

# %% [markdown]
# Eliminating extra variables

# %%
# Define the columns you want to keep
columns_to_keep = ['Accident_Index', 'Location_Easting_OSGR', 'Location_Northing_OSGR',
                   'Longitude', 'Latitude', 'Police_Force', 'Accident_Severity',
                   'Number_of_Vehicles', 'Number_of_Casualties', 'Date', 'Day_of_Week',
                   'Time', 'Local_Authority_(District)', 'Local_Authority_(Highway)',
                   '1st_Road_Class', '1st_Road_Number', 'Road_Type', 'Speed_limit',
                   'Junction_Detail', 'Junction_Control', '2nd_Road_Class',
                   '2nd_Road_Number', 'Pedestrian_Crossing-Human_Control',
                   'Pedestrian_Crossing-Physical_Facilities', 'Light_Conditions',
                   'Weather_Conditions', 'Road_Surface_Conditions',
                   'Special_Conditions_at_Site', 'Carriageway_Hazards',
                   'Urban_or_Rural_Area', 'Did_Police_Officer_Attend_Scene_of_Accident',
                   'LSOA_of_Accident_Location', 'Casualty_Class', 'Sex_of_Casualty',
                   'Age_of_Casualty', 'Age_Band_of_Casualty', 'Casualty_Severity',
                   'Pedestrian_Location', 'Pedestrian_Movement', 'Car_Passenger',
                   'Bus_or_Coach_Passenger', 'Pedestrian_Road_Maintenance_Worker',
                   'Casualty_Type', 'Casualty_Home_Area_Type', 'Vehicle_Type',
                   'Towing_and_Articulation', 'Vehicle_Manoeuvre',
                   'Vehicle_Location-Restricted_Lane', 'Junction_Location',
                   'Skidding_and_Overturning', 'Hit_Object_in_Carriageway',
                   'Vehicle_Leaving_Carriageway', 'Hit_Object_off_Carriageway',
                   '1st_Point_of_Impact', 'Was_Vehicle_Left_Hand_Drive?',
                   'Journey_Purpose_of_Driver', 'Sex_of_Driver', 'Age_of_Driver',
                   'Age_Band_of_Driver', 'Engine_Capacity_(CC)', 'Propulsion_Code',
                   'Age_of_Vehicle', 'Driver_IMD_Decile', 'Driver_Home_Area_Type']

# Create a new DataFrame with only the selected columns
final_data_subset = final_data[columns_to_keep].copy()

# %% [markdown]
# Eliminating Duplicates

# %%
# Drop duplicate rows
final_data_subset.drop_duplicates(inplace=True)

# %% [markdown]
# detect and remove outliers

# %%
import cufflinks as cf
import plotly.offline as pyo

# Identify numerical columns
numerical_columns = df.select_dtypes(include=['number']).columns

# Enable the offline mode for Plotly
pyo.init_notebook_mode(connected=True)

# Visualize the distribution of numerical columns using box plots
df[numerical_columns].iplot(kind='box')

# %%
# import dataset
accidents = pd.read_csv("/kaggle/input/dataset0/accidents.csv")

# take a look at first entries
accidents.head()

# %%
accidents.info()

# %%
# number of rows by number of columns
accidents.shape

# %%
# check for 'NaN' values
accidents.isnull().sum()

# %%
# Option 1: Remove rows with missing values
accidents_cleaned = accidents.dropna()

# %%
# Option 2: Impute missing values (e.g., fill with mean, median, mode)
numeric_columns = accidents.select_dtypes(include=['float64', 'int64']).columns
accidents_imputed = accidents.copy()
for column in numeric_columns:
    accidents_imputed[column] = accidents[column].fillna(accidents[column].mean())

# %%
# Option 3: Impute missing values using more advanced techniques (e.g., predictive modeling)
from sklearn.impute import SimpleImputer

imputer = SimpleImputer(strategy='mean')
accidents_imputed_sklearn = accidents.copy()
accidents_imputed_sklearn[numeric_columns] = imputer.fit_transform(accidents[numeric_columns])

# %%
# After handling missing values, you can save the cleaned dataset to a new file
accidents_cleaned.to_csv("accidents_cleaned.csv", index=False)
accidents_imputed.to_csv("accidents_imputed.csv", index=False)
accidents_imputed_sklearn.to_csv("accidents_imputed_sklearn.csv", index=False)

# %%
# Check the columns in the dataset
print("Original columns:\n", accidents.columns)

# %%
# List of columns to keep (modify this list based on your requirements)
columns_to_keep = ['Accident_Index', 'Location_Easting_OSGR', 'Location_Northing_OSGR', 'Longitude', 'Latitude', 'Police_Force', 'Accident_Severity', 'Number_of_Vehicles', 'Number_of_Casualties', 'Date', 'Day_of_Week', 'Time', 'Local_Authority_(District)', 'Local_Authority_(Highway)', '1st_Road_Class', '1st_Road_Number', 'Road_Type', 'Speed_limit', 'Junction_Detail', 'Junction_Control', '2nd_Road_Class', '2nd_Road_Number', 'Pedestrian_Crossing-Human_Control', 'Pedestrian_Crossing-Physical_Facilities', 'Light_Conditions', 'Weather_Conditions', 'Road_Surface_Conditions', 'Special_Conditions_at_Site', 'Carriageway_Hazards', 'Urban_or_Rural_Area', 'Did_Police_Officer_Attend_Scene_of_Accident', 'LSOA_of_Accident_Location']

# %%
# Keep only the selected columns
print("Column names in the dataset:\n", accidents.columns)

# %%
# Check the columns after selection
print("Selected columns:\n", accidents.columns)

# %%
# After eliminating extra variables, you can save the updated dataset to a new file
accidents.to_csv("accidents_columns.csv", index=False)

# %%
# Check the shape of the dataset before removing duplicates
print("Shape of the dataset before removing duplicates:", accidents.shape)

# %%
# Remove duplicates
accidents_no_duplicates = accidents.drop_duplicates()

# %%
# Check the shape of the dataset after removing duplicates
print("Shape of the dataset after removing duplicates:", accidents_no_duplicates.shape)

# %%
# Optionally, you can save the dataset without duplicates to a new file
accidents_no_duplicates.to_csv("accidents_no_duplicates.csv", index=False)

# %%
import cufflinks as cf
import plotly.offline

# %%
# Use Cufflinks with Plotly in offline mode
cf.go_offline()

# Create a box plot to visualize the distribution of a numeric variable
# For example, let's use the 'Number_of_Vehicles' column
accidents['Number_of_Vehicles'].iplot(kind='box', title='Box Plot of Number of Vehicles')

# %%
# Detect and remove outliers based on a threshold
# For example, let's remove outliers for the 'Number_of_Vehicles' column using the Interquartile Range (IQR) method
Q1 = accidents['Number_of_Vehicles'].quantile(0.25)
Q3 = accidents['Number_of_Vehicles'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# %%
# Remove outliers
accidents_no_outliers = accidents[(accidents['Number_of_Vehicles'] >= lower_bound) & (accidents['Number_of_Vehicles'] <= upper_bound)]

# %%
#Check the shape of the dataset after removing outliers
print("Shape of the dataset after removing outliers:", accidents_no_outliers.shape)

# Optional: Create a box plot after removing outliers to verify
accidents_no_outliers['Number_of_Vehicles'].iplot(kind='box', title='Box Plot of Number of Vehicles (Without Outliers)')

# %% [markdown]
# فاصل

# %%
# Create a function to categorize accident severity
def category(accident_severity):
    if accident_severity == 1:
        return 'Fatal'
    elif accident_severity == 2:
        return 'Serious'
    elif accident_severity == 3:
        return 'Slight'
    else:
        return 'Unknown'

# %%
# Apply the function and add it as 'Accident_Category' column
accidents['Accident_Category'] = accidents['Accident_Severity'].apply(category)

# %%
data1=pd.read_csv('/kaggle/input/uk-accidents-10-years-history-with-many-variables/Accidents0514.csv')
